# %%
#module 1
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/SHAIK NASIR AHAMMED/AI_Project/data/smart_home_energy_complete_dataset123.csv");

# %%
df.head()
# Out:
#          timestamp    fridge  wine_cellar  garage_door  microwave  \
# 0  01-01-2024 0.00  0.087454     0.048248     0.021401   0.134789
# 1  01-01-2024 1.00  0.145071     0.083983     0.032914   0.107467
# 2  01-01-2024 2.00  0.123199     0.064375     0.013190   0.088829
# 3  01-01-2024 3.00  0.109866     0.086075     0.000603   0.126888
# 4  01-01-2024 4.00  0.065602     0.070517     0.025947   0.165536
#
#    living_room_appliances  temperature   humidity  visibility  wind_speed  \
# 0                0.388502    25.116817  67.448290    2.198624    3.882553
# 1                0.402047    27.893934  88.645228    6.779476    9.905035
# 2                0.188399    33.192758  36.021163    8.239973    1.540610
# 3                0.300399    29.151057  56.359830    8.120698    0.300457
# 4                0.240081    15.909185  88.641774    7.477148    1.436447
#
#    cloud_cover     pressure  total_energy_consumption
# 0    78.964190  1000.861759                  0.680394
# 1    52.888059  1016.551026                  0.771482
# 2    16.688924   990.780460                  0.477993
# 3    44.504108  1029.305092                  0.623831
# 4    92.434537  1017.450593                  0.567682

# %%
df.tail()
# Out:
#              timestamp    fridge  wine_cellar  garage_door  microwave  \
# 4340  29-06-2024 20.00  0.094258     0.066839     0.015247   0.163037
# 4341  29-06-2024 21.00  0.054836     0.045252     0.018003   0.071835
# 4342  29-06-2024 22.00  0.132049     0.026955     0.021027   0.095991
# 4343  29-06-2024 23.00  0.132634     0.037836     0.004943   0.193138
# 4344   30-06-2024 0.00  0.108800     0.035045     0.002118   0.048434
#
#       living_room_appliances  temperature   humidity  visibility  wind_speed  \
# 4340                0.317910    30.879014  47.365051    6.914592    5.702042
# 4341                0.232611    34.032545  42.456682    7.948109   13.107345
# 4342                0.170091    19.615308  75.871922    8.866895    8.186988
# 4343                0.407392    27.341084  86.127369    4.529984    1.011850
# 4344                0.259990    32.743935  33.168341    8.302869    7.620728
#
#       cloud_cover     pressure  total_energy_consumption
# 4340    97.038314  1005.492105                  0.657290
# 4341     5.507086  1003.705046                  0.422537
# 4342    94.587739   984.288199                  0.446113
# 4343    15.926706  1019.744498                  0.775944
# 4344    37.698818   994.179514                  0.454388

# %%
df.shape
# Out:
# (4345, 13)

# %%
df.columns
# Out:
# Index(['timestamp', 'fridge', 'wine_cellar', 'garage_door', 'microwave',
#        'living_room_appliances', 'temperature', 'humidity', 'visibility',
#        'wind_speed', 'cloud_cover', 'pressure', 'total_energy_consumption'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4345 entries, 0 to 4344
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   timestamp                 4345 non-null   object
#  1   fridge                    4345 non-null   float64
#  2   wine_cellar               4345 non-null   float64
#  3   garage_door               4345 non-null   float64
#  4   microwave                 4345 non-null   float64
#  5   living_room_appliances    4345 non-null   float64
#  6   temperature               4345 non-null   float64
#  7   humidity                  4345 non-null   float64
#  8   visibility                4345 non-null   float64
#  9   wind_speed                4345 non-null   float64
#  10  cloud_cover               4345 non-null   float64
#  11  pressure                  4345 non-null   float64
#  12  total_energy_consumption  4345 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 441.4+ KB

# %%
df['timestamp'].head(10)
# Out:
# 0    01-01-2024 0.00
# 1    01-01-2024 1.00
# 2    01-01-2024 2.00
# 3    01-01-2024 3.00
# 4    01-01-2024 4.00
# 5    01-01-2024 5.00
# 6    01-01-2024 6.00
# 7    01-01-2024 7.00
# 8    01-01-2024 8.00
# 9    01-01-2024 9.00
# Name: timestamp, dtype: object

# %%
df['timestamp']=df['timestamp'].astype(str)
df['timestamp']=df['timestamp'].str.replace('.00',':00',regex=False)

# %%
df['timestamp'] = pd.to_datetime(
    df['timestamp'],
    format='%d-%m-%Y %H:%M',
    errors='coerce'
)

# %%
df['timestamp'].isnull().sum()
# Out:
# 0

# %%
df.set_index('timestamp', inplace=True)

# %%
df.resample('D').sum()
# Out:
#               fridge  wine_cellar  garage_door  microwave  \
# timestamp
# 2024-01-01  2.256390     1.455876     0.619609   2.791495
# 2024-01-02  2.300073     1.225762     0.615966   2.799939
# 2024-01-03  2.413008     1.292919     0.433910   2.059320
# 2024-01-04  2.423978     1.372301     0.588047   2.044959
# 2024-01-05  2.331872     1.517984     0.562572   2.246653
# ...              ...          ...          ...        ...
# 2024-06-26  2.483341     1.622156     0.552095   2.506688
# 2024-06-27  2.276598     1.381480     0.577687   2.426347
# 2024-06-28  2.436257     1.229328     0.582074   2.280984
# 2024-06-29  2.450645     1.229260     0.599788   2.540232
# 2024-06-30  0.108800     0.035045     0.002118   0.048434
#
#             living_room_appliances  temperature     humidity  visibility  \
# timestamp
# 2024-01-01                8.220350   595.882164  1464.244749  139.289170
# 2024-01-02                6.328915   615.429134  1389.745129  130.787746
# 2024-01-03                7.165744   616.359285  1289.688598  138.938880
# 2024-01-04                6.215111   555.790155  1341.187445  125.474129
# 2024-01-05                7.816897   610.270007  1423.266118  117.854880
# ...                            ...          ...          ...         ...
# 2024-06-26                7.310724   641.133286  1466.723082  104.955884
# 2024-06-27                7.198704   576.867890  1397.385894  116.167726
# 2024-06-28                7.350014   542.668809  1496.681836  131.848337
# 2024-06-29                7.600166   601.765697  1542.404864  134.751437
# 2024-06-30                0.259990    32.743935    33.168341    8.302869
#
#             wind_speed  cloud_cover      pressure  total_energy_consumption
# timestamp
# 2024-01-01  136.386881  1068.397101  24081.397332                 15.343720
# 2024-01-02  165.498388  1177.044026  24102.958328                 13.270655
# 2024-01-03  205.435236  1205.139970  24105.522945                 13.364901
# 2024-01-04  190.966525  1155.366074  24133.574332                 12.644395
# 2024-01-05  167.282834  1047.076986  24085.982094                 14.475978
# ...                ...          ...           ...                       ...
# 2024-06-26  196.298737  1326.235142  24263.562056                 14.475003
# 2024-06-27  205.797997   983.674953  24146.706479                 13.860815
# 2024-06-28  163.013612  1303.672668  24211.743195                 13.878657
# 2024-06-29  175.143499  1493.633563  24238.633727                 14.420091
# 2024-06-30    7.620728    37.698818    994.179514                  0.454388
#
# [182 rows x 12 columns]

# %%
df[['fridge','microwave','living_room_appliances']].plot(figsize=(10,4))
plt.title("Appliance Energy Usage")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df.index, df['total_energy_consumption'])
plt.title("Total Energy Consumption Over Time")
plt.xlabel("Time")
plt.ylabel("Energy Consumption")
plt.show()

# %%
df.head()
# Out:
#                        fridge  wine_cellar  garage_door  microwave  \
# timestamp
# 2024-01-01 00:00:00  0.087454     0.048248     0.021401   0.134789
# 2024-01-01 01:00:00  0.145071     0.083983     0.032914   0.107467
# 2024-01-01 02:00:00  0.123199     0.064375     0.013190   0.088829
# 2024-01-01 03:00:00  0.109866     0.086075     0.000603   0.126888
# 2024-01-01 04:00:00  0.065602     0.070517     0.025947   0.165536
#
#                      living_room_appliances  temperature   humidity  \
# timestamp
# 2024-01-01 00:00:00                0.388502    25.116817  67.448290
# 2024-01-01 01:00:00                0.402047    27.893934  88.645228
# 2024-01-01 02:00:00                0.188399    33.192758  36.021163
# 2024-01-01 03:00:00                0.300399    29.151057  56.359830
# 2024-01-01 04:00:00                0.240081    15.909185  88.641774
#
#                      visibility  wind_speed  cloud_cover     pressure  \
# timestamp
# 2024-01-01 00:00:00    2.198624    3.882553    78.964190  1000.861759
# 2024-01-01 01:00:00    6.779476    9.905035    52.888059  1016.551026
# 2024-01-01 02:00:00    8.239973    1.540610    16.688924   990.780460
# 2024-01-01 03:00:00    8.120698    0.300457    44.504108  1029.305092
# 2024-01-01 04:00:00    7.477148    1.436447    92.434537  1017.450593
#
#                      total_energy_consumption
# timestamp
# 2024-01-01 00:00:00                  0.680394
# 2024-01-01 01:00:00                  0.771482
# 2024-01-01 02:00:00                  0.477993
# 2024-01-01 03:00:00                  0.623831
# 2024-01-01 04:00:00                  0.567682

# %%
plt.figure(figsize=(10,4))
plt.plot(df.index, df['total_energy_consumption'])
plt.title("Total Energy Consumption Over Time")
plt.xlabel("Time")
plt.ylabel("Energy Consumption")
plt.show()

# %%
#module 2

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df.isnull().sum()
# Out:
# fridge                      0
# wine_cellar                 0
# garage_door                 0
# microwave                   0
# living_room_appliances      0
# temperature                 0
# humidity                    0
# visibility                  0
# wind_speed                  0
# cloud_cover                 0
# pressure                    0
# total_energy_consumption    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
daily_df = df.resample('D').sum()

# %%
daily_df.head()
# Out:
#               fridge  wine_cellar  garage_door  microwave  \
# timestamp
# 2024-01-01  2.256390     1.455876     0.619609   2.791495
# 2024-01-02  2.300073     1.225762     0.615966   2.799939
# 2024-01-03  2.413008     1.292919     0.433910   2.059320
# 2024-01-04  2.423978     1.372301     0.588047   2.044959
# 2024-01-05  2.331872     1.517984     0.562572   2.246653
#
#             living_room_appliances  temperature     humidity  visibility  \
# timestamp
# 2024-01-01                8.220350   595.882164  1464.244749  139.289170
# 2024-01-02                6.328915   615.429134  1389.745129  130.787746
# 2024-01-03                7.165744   616.359285  1289.688598  138.938880
# 2024-01-04                6.215111   555.790155  1341.187445  125.474129
# 2024-01-05                7.816897   610.270007  1423.266118  117.854880
#
#             wind_speed  cloud_cover      pressure  total_energy_consumption
# timestamp
# 2024-01-01  136.386881  1068.397101  24081.397332                 15.343720
# 2024-01-02  165.498388  1177.044026  24102.958328                 13.270655
# 2024-01-03  205.435236  1205.139970  24105.522945                 13.364901
# 2024-01-04  190.966525  1155.366074  24133.574332                 12.644395
# 2024-01-05  167.282834  1047.076986  24085.982094                 14.475978

# %%
plt.figure(figsize=(10,4))
plt.plot(daily_df.index, daily_df['total_energy_consumption'])
plt.title("Daily Total Energy Consumption")
plt.xlabel("Date")
plt.ylabel("Energy Consumption")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
daily_df['scaled_energy'] = scaler.fit_transform(
    daily_df[['total_energy_consumption']]
)

# %%
train = daily_df[:-30]   # all days except last 30
test = daily_df[-30:]    # last 30 days

# %%
#module 3

# %%
daily_df['day'] = daily_df.index.day
daily_df['month'] = daily_df.index.month
daily_df['dayofweek'] = daily_df.index.dayofweek

# %%
daily_df['lag_1'] = daily_df['total_energy_consumption'].shift(1)

# %%
daily_df['rolling_7'] = daily_df['total_energy_consumption'].rolling(window=7).mean()

# %%
daily_df.dropna(inplace=True)
daily_df.head()
# Out:
#               fridge  wine_cellar  garage_door  microwave  \
# timestamp
# 2024-01-07  2.277587     1.339394     0.570367   2.340520
# 2024-01-08  2.334462     1.471421     0.574728   2.705527
# 2024-01-09  2.391090     1.465745     0.619107   2.357510
# 2024-01-10  2.406878     1.502662     0.647524   2.154884
# 2024-01-11  2.647145     1.528726     0.620686   2.325740
#
#             living_room_appliances  temperature     humidity  visibility  \
# timestamp
# 2024-01-07                8.641826   615.942970  1569.383330  137.253880
# 2024-01-08                8.262739   585.152542  1427.258757  150.349975
# 2024-01-09                6.509494   597.762072  1386.613031  132.264781
# 2024-01-10                6.408242   650.830857  1397.488970  112.955331
# 2024-01-11                7.300573   648.771987  1406.262725  122.483418
#
#             wind_speed  cloud_cover      pressure  total_energy_consumption  \
# timestamp
# 2024-01-07  186.086150  1126.967998  23985.666752                 15.169694
# 2024-01-08  209.939384  1252.924923  24168.965041                 15.348876
# 2024-01-09  223.773755  1112.963637  24015.477682                 13.342947
# 2024-01-10  172.074270  1378.862367  24136.254939                 13.120190
# 2024-01-11  174.005504  1378.249834  24151.160026                 14.422869
#
#             scaled_energy  day  month  dayofweek      lag_1  rolling_7
# timestamp
# 2024-01-07       0.937082    7      1          6  13.946810  14.030879
# 2024-01-08       0.948493    8      1          0  15.169694  14.031616
# 2024-01-09       0.820754    9      1          1  15.348876  14.041943
# 2024-01-10       0.806568   10      1          2  13.342947  14.006984
# 2024-01-11       0.889524   11      1          3  13.120190  14.261052

# %%
df.head()
# Out:
#                        fridge  wine_cellar  garage_door  microwave  \
# timestamp
# 2024-01-01 00:00:00  0.087454     0.048248     0.021401   0.134789
# 2024-01-01 01:00:00  0.145071     0.083983     0.032914   0.107467
# 2024-01-01 02:00:00  0.123199     0.064375     0.013190   0.088829
# 2024-01-01 03:00:00  0.109866     0.086075     0.000603   0.126888
# 2024-01-01 04:00:00  0.065602     0.070517     0.025947   0.165536
#
#                      living_room_appliances  temperature   humidity  \
# timestamp
# 2024-01-01 00:00:00                0.388502    25.116817  67.448290
# 2024-01-01 01:00:00                0.402047    27.893934  88.645228
# 2024-01-01 02:00:00                0.188399    33.192758  36.021163
# 2024-01-01 03:00:00                0.300399    29.151057  56.359830
# 2024-01-01 04:00:00                0.240081    15.909185  88.641774
#
#                      visibility  wind_speed  cloud_cover     pressure  \
# timestamp
# 2024-01-01 00:00:00    2.198624    3.882553    78.964190  1000.861759
# 2024-01-01 01:00:00    6.779476    9.905035    52.888059  1016.551026
# 2024-01-01 02:00:00    8.239973    1.540610    16.688924   990.780460
# 2024-01-01 03:00:00    8.120698    0.300457    44.504108  1029.305092
# 2024-01-01 04:00:00    7.477148    1.436447    92.434537  1017.450593
#
#                      total_energy_consumption
# timestamp
# 2024-01-01 00:00:00                  0.680394
# 2024-01-01 01:00:00                  0.771482
# 2024-01-01 02:00:00                  0.477993
# 2024-01-01 03:00:00                  0.623831
# 2024-01-01 04:00:00                  0.567682

# %%
#Feature Engineering
daily_df = df.resample('D').sum()

# %%
features = daily_df.copy()

# %%
# Day of month (1–31)
features['day'] = features.index.day

# Month (1–12)
features['month'] = features.index.month

# Day of week (0 = Monday, 6 = Sunday)
features['day_of_week'] = features.index.dayofweek

# Weekend flag (Saturday & Sunday)
features['is_weekend'] = features['day_of_week'].apply(
    lambda x: 1 if x >= 5 else 0
)

# %%
# Previous day energy consumption
features['lag_1'] = features['total_energy_consumption'].shift(1)

# Energy consumption 7 days ago
features['lag_7'] = features['total_energy_consumption'].shift(7)

# %%
# 7-day rolling mean (weekly trend)
features['rolling_mean_7'] = features['total_energy_consumption'].rolling(7).mean()

# 14-day rolling mean (bi-weekly trend)
features['rolling_mean_14'] = features['total_energy_consumption'].rolling(14).mean()

# 7-day rolling standard deviation (volatility)
features['rolling_std_7'] = features['total_energy_consumption'].rolling(7).std()

# %%
features = features.dropna()

# %%
features.head()
features.columns
features.shape
# Out:
# (169, 21)

# %%
# Temperature change
features['temp_diff'] = features['temperature'].diff()

# Humidity change
features['humidity_diff'] = features['humidity'].diff()

# %%
features.dropna(inplace=True)

# %%
#Aggregation


# List of device-level energy columns
device_columns = [
    'fridge',
    'wine_cellar',
    'garage_door',
    'microwave',
    'living_room_appliances'
]

# %%
device_long_df = daily_df[device_columns].reset_index().melt(
    id_vars='timestamp',
    value_vars=device_columns,
    var_name='device',
    value_name='energy_kwh'
)

# %%
device_energy_mean = (
    device_long_df
    .groupby('device')['energy_kwh']
    .mean()
    .reset_index()
)
device_energy_mean
# Out:
#                    device  energy_kwh
# 0                  fridge    2.380737
# 1             garage_door    0.596994
# 2  living_room_appliances    7.244323
# 3               microwave    2.399287
# 4             wine_cellar    1.415401

# %%
#module 4
# Target variable
y = features['total_energy_consumption']

# Input features
X = features.drop(columns=['total_energy_consumption'])

# %%
# Step 3: Split data into train and test sets (time-based)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=False
)

# %%
# Step 4: Initialize and train Linear Regression model
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Step 5: Predict energy consumption
y_pred = lr_model.predict(X_test)

# %%
# Step 6: Evaluate model performance
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("Avg MAE:", np.mean(mae))
print("Avg RMSE:", np.mean(rmse))
# Out:
# Avg MAE: 5.266805429690766e-09
# Avg RMSE: 7.542432690981355e-09

# %%
# Step 7: Plot actual vs predicted energy consumption (time-based, PDF compliant)

import matplotlib.pyplot as plt
import pandas as pd

# Define cutoff date
cutoff_date = pd.to_datetime("2024-06-25")

# Filter test data till cutoff date
y_test_cut = y_test[y_test.index <= cutoff_date]

# Align predictions with filtered test data
y_pred_cut = y_pred[:len(y_test_cut)]

# Plot using DATE index (correct as per Module 4)
plt.figure(figsize=(10, 4))
plt.plot(y_test_cut.index, y_test_cut.values, label="Actual")
plt.plot(y_test_cut.index, y_pred_cut, label="Predicted")

plt.title("Baseline Linear Regression – Daily Energy Prediction")
plt.xlabel("Date")
plt.ylabel("Energy Consumption (kWh)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Evaluation
baseline_mae = mean_absolute_error(y_test_base, y_pred_base)
baseline_rmse = mean_squared_error(y_test_base, y_pred_base, squared=False)
baseline_r2 = r2_score(y_test_base, y_pred_base)

print("Baseline model metrics computed")

# %%
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': lr_model.coef_
})

feature_importance.sort_values(by='Coefficient', ascending=False)
# Out:
#                    Feature   Coefficient
# 2              garage_door  1.000000e+00
# 4   living_room_appliances  1.000000e+00
# 3                microwave  1.000000e+00
# 0                   fridge  1.000000e+00
# 1              wine_cellar  1.000000e+00
# 17          rolling_mean_7  3.959565e-09
# 16                   lag_7  7.772789e-10
# 13             day_of_week  6.352451e-10
# 12                   month  5.895651e-10
# 5              temperature  4.258686e-11
# 21           humidity_diff  6.042192e-12
# 10                pressure -7.718239e-14
# 6                 humidity -4.744293e-12
# 9              cloud_cover -6.018644e-12
# 11                     day -1.660097e-11
# 7               visibility -2.005355e-11
# 8               wind_speed -2.964612e-11
# 20               temp_diff -4.554034e-11
# 19           rolling_std_7 -1.512617e-09
# 14              is_weekend -1.864533e-09
# 15                   lag_1 -3.579369e-09
# 18         rolling_mean_14 -6.976360e-09

# %%
results = X_test.copy()
results['Actual_Energy'] = y_test.values
results['Predicted_Energy'] = y_pred

results.head()
# Out:
#               fridge  wine_cellar  garage_door  microwave  \
# timestamp
# 2024-05-28  2.476868     1.316405     0.654589   2.418409
# 2024-05-29  2.395995     1.449565     0.560530   2.159006
# 2024-05-30  2.328548     1.331285     0.650794   2.334004
# 2024-05-31  2.246900     1.595011     0.609166   2.425615
# 2024-06-01  2.222027     1.404465     0.577936   2.405308
#
#             living_room_appliances  temperature     humidity  visibility  \
# timestamp
# 2024-05-28                7.728674   564.567040  1479.535375  119.759256
# 2024-05-29                7.749939   585.397158  1455.483612  152.670433
# 2024-05-30                7.373133   587.084042  1530.049562  127.464372
# 2024-05-31                6.891567   630.990012  1548.657269  158.172242
# 2024-06-01                7.314352   614.588696  1407.981274  143.493725
#
#             wind_speed  cloud_cover  ...  is_weekend      lag_1      lag_7  \
# timestamp                            ...
# 2024-05-28  197.545852  1007.001869  ...           0  14.279750  14.126222
# 2024-05-29  164.478581   891.451939  ...           0  14.594945  14.547556
# 2024-05-30  164.445067  1284.307937  ...           0  14.315037  14.126672
# 2024-05-31  153.743710  1062.387788  ...           0  14.017764  14.185850
# 2024-06-01  168.379326  1253.896651  ...           1  13.768258  14.445742
#
#             rolling_mean_7  rolling_mean_14  rolling_std_7  temp_diff  \
# timestamp
# 2024-05-28       14.379808        14.315789       0.182642 -24.384487
# 2024-05-29       14.346590        14.321841       0.167571  20.830118
# 2024-05-30       14.331032        14.313959       0.194314   1.686884
# 2024-05-31       14.271376        14.352374       0.287887  43.905970
# 2024-06-01       14.196854        14.267813       0.302381 -16.401316
#
#             humidity_diff  Actual_Energy  Predicted_Energy
# timestamp
# 2024-05-28      43.385067      14.594945         14.594945
# 2024-05-29     -24.051763      14.315037         14.315037
# 2024-05-30      74.565950      14.017764         14.017764
# 2024-05-31      18.607707      13.768258         13.768258
# 2024-06-01    -140.675995      13.924088         13.924088
#
# [5 rows x 24 columns]

# %% [markdown]
# TASK ASSIGNED
#
# Students_data.xlsx
#
# sheet1= details of the students
#
# sheet2 : marks of the students
#
# Load both sheets from student_data.xlsx into two separate pandas DataFrames. give answer for this

# %%
import pandas as pd

# Load Sheet 1: Student details
df_students = pd.read_excel("C:/Users/SHAIK NASIR AHAMMED/Downloads/Students_data.xlsx", sheet_name="sheet1")

# Load Sheet 2: Student marks
df_marks = pd.read_excel("C:/Users/SHAIK NASIR AHAMMED/Downloads/Students_data.xlsx", sheet_name="sheet2")

# Display first few rows of both DataFrames
print("Student Details:")
display(df_students.head())

print("Student Marks:")
display(df_marks.head())
# Out:
# Student Details:
#    Student_ID          Name Department  Year                   Email
# 0         101    Amit Kumar        CSE     2    amit.cse@example.com
# 1         102     Sara Khan        ECE     3    sara.ece@example.com
# 2         103   Rahul Verma         ME     1    rahul.me@example.com
# 3         104  Priya Sharma        CSE     4   priya.cse@example.com
# 4         105  Anjali Singh        EEE     2  anjali.eee@example.com
# Student Marks:
#    Student_ID  Maths  Physics  Computer_Science  Total
# 0         101     85       78                90    253
# 1         102     88       82                76    246
# 2         103     70       75                68    213
# 3         104     92       89                95    276
# 4         105     80       77                85    242

# %%
# ==============================
# Module 5: LSTM Model Development
# ==============================

# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Suppress TensorFlow warnings
tf.get_logger().setLevel('ERROR')

# %%
# Target column
target_col = 'total_energy_consumption'

# Feature columns
feature_cols = features.columns.drop(target_col)

# Convert to NumPy arrays
X = features[feature_cols].values
y = features[[target_col]].values

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# %%
#Create Sequences for LSTM
def create_sequences(X, y, time_steps=14):
    Xs, ys = [], []
    for i in range(time_steps, len(X)):
        Xs.append(X[i-time_steps:i])
        ys.append(y[i])
    return np.array(Xs), np.array(ys)

TIME_STEPS = 14

X_seq, y_seq = create_sequences(X_scaled, y_scaled, TIME_STEPS)

# %%
#Time-Series Cross Validation
tscv = TimeSeriesSplit(n_splits=3)

# %%
#Build LSTM Model
def build_lstm_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(
            64,
            activation='tanh',
            kernel_regularizer=l2(0.0005)
        ),
        Dropout(0.2),
        Dense(1)
    ])
    
    model.compile(
        optimizer='adam',
        loss='mse'
    )
    
    return model

# %%
#Early Stopping (PREVENT OVERFITTING)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# %%
#Cross-Validation Training Loop (SCALED EVALUATION)
mae_scores = []
rmse_scores = []

for fold, (train_idx, test_idx) in enumerate(tscv.split(X_seq)):
    print(f"\nTraining Fold {fold + 1}")
    
    X_train, X_test = X_seq[train_idx], X_seq[test_idx]
    y_train, y_test = y_seq[train_idx], y_seq[test_idx]
    
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2])
    )
    
    model.fit(
        X_train,
        y_train,
        validation_split=0.2,
        epochs=150,
        batch_size=32,
        callbacks=[early_stopping],
        verbose=0
    )
    
    # Predict (on scaled values)
    y_pred = model.predict(X_test, verbose=0)
    
    # Evaluate on scaled values → errors around 0–1
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    mae_scores.append(mae)
    rmse_scores.append(rmse)
    
    print(f"MAE: {mae:.3f}, RMSE: {rmse:.3f}")
# Out:
# Training Fold 1
# MAE: 0.046, RMSE: 0.053
#
# Training Fold 2
# MAE: 0.033, RMSE: 0.042
#
# Training Fold 3
# MAE: 0.048, RMSE: 0.146

# %%
print("\nLSTM Average Performance")
print("Average MAE:", np.mean(mae_scores))
print("Average RMSE:", np.mean(rmse_scores))
# Out:
# LSTM Average Performance
# Average MAE: 0.042204129175134046
# Average RMSE: 0.08030293681338727

# %%
#HyperParameter Tuning

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error

tf.get_logger().setLevel('ERROR')

# %%
target_col = 'total_energy_consumption'
feature_cols = features.columns.drop(target_col)

X = features[feature_cols].values
y = features[[target_col]].values

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# %%
def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(time_steps, len(X)):
        Xs.append(X[i-time_steps:i])
        ys.append(y[i])
    return np.array(Xs), np.array(ys)

# %%
TIME_STEPS_LIST = [7, 14]
LSTM_UNITS_LIST = [32, 64]
DROPOUT_LIST = [0.2, 0.3]
LEARNING_RATE_LIST = [0.001, 0.0005]

# %%
def build_lstm_model(input_shape, units, dropout, lr):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(
            units,
            activation='tanh',
            kernel_regularizer=l2(0.0005)
        ),
        Dropout(dropout),
        Dense(1)
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss='mse'
    )
    
    return model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# %%
#hyperparameter tuning
tscv = TimeSeriesSplit(n_splits=3)

best_rmse = np.inf
best_params = None

for time_steps in TIME_STEPS_LIST:
    
    X_seq, y_seq = create_sequences(X_scaled, y_scaled, time_steps)
    
    for units in LSTM_UNITS_LIST:
        for dropout in DROPOUT_LIST:
            for lr in LEARNING_RATE_LIST:
                
                rmse_scores = []
                
                for train_idx, test_idx in tscv.split(X_seq):
                    
                    X_train, X_test = X_seq[train_idx], X_seq[test_idx]
                    y_train, y_test = y_seq[train_idx], y_seq[test_idx]
                    
                    model = build_lstm_model(
                        input_shape=(X_train.shape[1], X_train.shape[2]),
                        units=units,
                        dropout=dropout,
                        lr=lr
                    )
                    
                    model.fit(
                        X_train,
                        y_train,
                        validation_split=0.2,
                        epochs=100,
                        batch_size=32,
                        callbacks=[early_stopping],
                        verbose=0
                    )
                    
                    y_pred = model.predict(X_test, verbose=0)
                    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
                    rmse_scores.append(rmse)
                
                avg_rmse = np.mean(rmse_scores)
                
                print(
                    f"TIME_STEPS={time_steps}, UNITS={units}, "
                    f"DROPOUT={dropout}, LR={lr} → RMSE={avg_rmse:.4f}"
                )
                
                if avg_rmse < best_rmse:
                    best_rmse = avg_rmse
                    best_params = {
                        "time_steps": time_steps,
                        "units": units,
                        "dropout": dropout,
                        "learning_rate": lr
                    }
# Out:
# TIME_STEPS=7, UNITS=32, DROPOUT=0.2, LR=0.001 → RMSE=0.2637
# TIME_STEPS=7, UNITS=32, DROPOUT=0.2, LR=0.0005 → RMSE=0.9357
# TIME_STEPS=7, UNITS=32, DROPOUT=0.3, LR=0.001 → RMSE=0.6514
# TIME_STEPS=7, UNITS=32, DROPOUT=0.3, LR=0.0005 → RMSE=0.7461
# TIME_STEPS=7, UNITS=64, DROPOUT=0.2, LR=0.001 → RMSE=0.5461
# TIME_STEPS=7, UNITS=64, DROPOUT=0.2, LR=0.0005 → RMSE=0.3371
# TIME_STEPS=7, UNITS=64, DROPOUT=0.3, LR=0.001 → RMSE=0.3569
# TIME_STEPS=7, UNITS=64, DROPOUT=0.3, LR=0.0005 → RMSE=0.7537
# TIME_STEPS=14, UNITS=32, DROPOUT=0.2, LR=0.001 → RMSE=0.5678
# TIME_STEPS=14, UNITS=32, DROPOUT=0.2, LR=0.0005 → RMSE=0.5755
# TIME_STEPS=14, UNITS=32, DROPOUT=0.3, LR=0.001 → RMSE=0.7056
# TIME_STEPS=14, UNITS=32, DROPOUT=0.3, LR=0.0005 → RMSE=0.9014
# TIME_STEPS=14, UNITS=64, DROPOUT=0.2, LR=0.001 → RMSE=0.4075
# TIME_STEPS=14, UNITS=64, DROPOUT=0.2, LR=0.0005 → RMSE=0.6563
# TIME_STEPS=14, UNITS=64, DROPOUT=0.3, LR=0.001 → RMSE=0.4940
# TIME_STEPS=14, UNITS=64, DROPOUT=0.3, LR=0.0005 → RMSE=0.5169

# %%
print("\nBest Hyperparameters:")
print(best_params)
print("Best RMSE:", best_rmse)
# Out:
# Best Hyperparameters:
# {'time_steps': 7, 'units': 32, 'dropout': 0.2, 'learning_rate': 0.001}
# Best RMSE: 0.26366226750416905

# %%
# Save the trained LSTM model
model.save_weights("best_energy_weights.weights.h5")

import joblib
joblib.dump(scaler_X, "scaler_X.pkl")
joblib.dump(scaler_y, "scaler_y.pkl")

print("Model and scalers saved successfully")
# Out:
# Model and scalers saved successfully

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'app.py',
#  'best_energy_model.h5',
#  'best_energy_weights.weights.h5',
#  'data',
#  'lstm_energy_model.h5',
#  'scaler_X.pkl',
#  'scaler_y.pkl',
#  'Smart_Energy_Analysis.ipynb']

# %% [markdown]
# module 6

# %% [markdown]
# ## Model Evaluation
#
# In this module, the trained models were evaluated using the following metrics:
# - Mean Absolute Error (MAE)
# - Root Mean Square Error (RMSE)
# - R² Score
#
# The tuned LSTM model achieved better performance compared to the baseline model and was selected as the final model.
#
# ---
#
# ## Model Deployment using Flask API
#
# The selected LSTM model was integrated into a Flask-based REST API.
# The trained model weights and preprocessing scalers were loaded inside the API to enable real-time predictions.
#
# Due to TensorFlow compatibility constraints with Python 3.13, the API rebuilds the LSTM architecture and loads trained weights separately. This approach ensures reliable inference and is commonly used in real-world ML deployment scenarios.

# %%
#Module 6

# %%
import numpy as np
import joblib
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Load model WITHOUT compiling (FIXES YOUR ERROR)
lstm_model = load_model("best_energy_model.h5", compile=False)

# Load scalers
scaler_X = joblib.load("scaler_X.pkl")
scaler_y = joblib.load("scaler_y.pkl")

print("Model and scalers loaded successfully")
# Out:
# Model and scalers loaded successfully

# %%
# Recreate feature & target arrays
target_col = 'total_energy_consumption'
feature_cols = features.columns.drop(target_col)

X = features[feature_cols].values
y = features[[target_col]].values

# Scale using saved scalers
X_scaled = scaler_X.transform(X)
y_scaled = scaler_y.transform(y)

TIME_STEPS = 14

# %%
def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(time_steps, len(X)):
        Xs.append(X[i-time_steps:i])
        ys.append(y[i])
    return np.array(Xs), np.array(ys)

X_seq_eval, y_seq_eval = create_sequences(X_scaled, y_scaled, TIME_STEPS)

# %%
y_pred_eval = lstm_model.predict(X_seq_eval, verbose=0)

# %%
lstm_mae = mean_absolute_error(y_seq_eval, y_pred_eval)
lstm_rmse = np.sqrt(mean_squared_error(y_seq_eval, y_pred_eval))
lstm_r2 = r2_score(y_seq_eval, y_pred_eval)

print("Final Tuned LSTM Evaluation")
print("MAE:", lstm_mae)
print("RMSE:", lstm_rmse)
print("R² Score:", lstm_r2)
# Out:
# Final Tuned LSTM Evaluation
# MAE: 0.30088576173725207
# RMSE: 0.3054175212892011
# R² Score: -13.568082715853524

# %%
print("\nBaseline Linear Regression Evaluation")
print("MAE:", baseline_mae)
print("RMSE:", baseline_rmse)
print("R² Score:", baseline_r2)
# Out:
# Baseline Linear Regression Evaluation
# MAE: 5.266805429690766e-09
# RMSE: 7.542432690981355e-09
# R² Score: 1.0

# %%
if lstm_rmse < baseline_rmse:
    best_model_name = "Tuned LSTM"
else:
    best_model_name = "Linear Regression"

print("\nBest Performing Model:", best_model_name)
# Out:
# Best Performing Model: Linear Regression

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": ["Baseline Linear Regression", "Tuned LSTM"],
    "MAE": [baseline_mae, lstm_mae],
    "RMSE": [baseline_rmse, lstm_rmse],
    "R² Score": [baseline_r2, lstm_r2]
})

comparison
# Out:
#                         Model           MAE          RMSE   R² Score
# 0  Baseline Linear Regression  5.266805e-09  7.542433e-09   1.000000
# 1                  Tuned LSTM  3.008858e-01  3.054175e-01 -13.568083

# %%
def predict_energy_consumption(last_days_features):
    """
    last_days_features: list of last TIME_STEPS days feature vectors
    """
    input_data = np.array(last_days_features)
    
    # Scale
    input_scaled = scaler_X.transform(input_data)
    
    # Reshape for LSTM
    input_scaled = input_scaled.reshape(1, TIME_STEPS, input_scaled.shape[1])
    
    # Predict
    pred_scaled = lstm_model.predict(input_scaled, verbose=0)
    
    # Inverse scale
    prediction = scaler_y.inverse_transform(pred_scaled)
    
    return prediction[0][0]

# %%
# Dummy test input (random example)
sample_input = np.random.rand(TIME_STEPS, X.shape[1])

predicted_value = predict_energy_consumption(sample_input)

print("Predicted Energy Consumption:", predicted_value)
# Out:
# Predicted Energy Consumption: -3.6731212

# %%
import requests
import numpy as np

url = "http://127.0.0.1:5000/predict"

TIME_STEPS = 14
NUM_FEATURES = scaler_X.n_features_in_

sample_input = {
    "features": np.random.rand(TIME_STEPS, NUM_FEATURES).tolist()
}

response = requests.post(url, json=sample_input)
print(response.json())
# Out:
# {'predicted_energy_consumption': 0.0}

# %% [markdown]
# ## Flask API Implementation (app.py)
#
# ```python
# from flask import Flask, request, jsonify
# import numpy as np
# import joblib
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense, Dropout
#
# app = Flask(__name__)
#
# scaler_X = joblib.load("scaler_X.pkl")
# scaler_y = joblib.load("scaler_y.pkl")
#
# TIME_STEPS = 14
# NUM_FEATURES = scaler_X.n_features_in_
#
# def build_lstm_model():
#     model = Sequential()
#     model.add(LSTM(64, activation="tanh", input_shape=(TIME_STEPS, NUM_FEATURES)))
#     model.add(Dropout(0.2))
#     model.add(Dense(1))
#     return model
#
# model = build_lstm_model()
# model.load_weights("best_energy_weights.weights.h5")
#
# @app.route("/")
# def home():
#     return "Energy Consumption Prediction API is running"
#
# @app.route("/predict", methods=["POST"])
# def predict():
#     data = request.get_json()
#     arr = np.array(data["features"])
#     arr_scaled = scaler_X.transform(arr)
#     arr_scaled = arr_scaled.reshape(1, TIME_STEPS, NUM_FEATURES)
#     pred_scaled = model.predict(arr_scaled)
#     prediction = scaler_y.inverse_transform(pred_scaled)
#     return jsonify({"predicted_energy_consumption": float(max(prediction[0][0], 0.0))})

# %%
# Take last 14 rows from your actual dataset
real_input = X[-14:]  # X from your training notebook

sample_input = {
    "features": real_input.tolist()
}

response = requests.post(
    "http://127.0.0.1:5000/predict",
    json=sample_input
)

print(response.json())
# Out:
# {'predicted_energy_consumption': 8.545315742492676}

# %%
#module 7

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a safe copy for dashboard work
dashboard_df = df.copy()

# Ensure datetime index (works whether timestamp is column or index)
if 'timestamp' in dashboard_df.columns:
    dashboard_df['timestamp'] = pd.to_datetime(dashboard_df['timestamp'])
    dashboard_df.set_index('timestamp', inplace=True)
else:
    dashboard_df.index = pd.to_datetime(dashboard_df.index)

print("Dashboard dataframe ready")
# Out:
# Dashboard dataframe ready

# %%
hourly_consumption = dashboard_df['total_energy_consumption'].resample('H').mean()

plt.figure(figsize=(12,4))
plt.plot(hourly_consumption)
plt.title("Hourly Energy Consumption")
plt.xlabel("Time")
plt.ylabel("Energy Consumption")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SHAIK NASIR AHAMMED\AppData\Local\Temp\ipykernel_15100\4162259594.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_consumption = dashboard_df['total_energy_consumption'].resample('H').mean()

# %%
daily_consumption = dashboard_df['total_energy_consumption'].resample('D').sum()

plt.figure(figsize=(12,4))
plt.plot(daily_consumption)
plt.title("Daily Energy Consumption")
plt.xlabel("Date")
plt.ylabel("Total Energy Consumption")
plt.tight_layout()
plt.show()

# %%
weekly_consumption = dashboard_df['total_energy_consumption'].resample('W').sum()

plt.figure(figsize=(12,4))
plt.plot(weekly_consumption)
plt.title("Weekly Energy Consumption")
plt.xlabel("Week")
plt.ylabel("Total Energy Consumption")
plt.tight_layout()
plt.show()

# %%
monthly_consumption = dashboard_df['total_energy_consumption'].resample('M').sum()

plt.figure(figsize=(12,4))
plt.plot(monthly_consumption)
plt.title("Monthly Energy Consumption")
plt.xlabel("Month")
plt.ylabel("Total Energy Consumption")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SHAIK NASIR AHAMMED\AppData\Local\Temp\ipykernel_15100\2230888712.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_consumption = dashboard_df['total_energy_consumption'].resample('M').sum()

# %%
device_columns = [
    col for col in dashboard_df.columns
    if col != 'total_energy_consumption'
]

print("Device columns:", device_columns)
# Out:
# Device columns: ['fridge', 'wine_cellar', 'garage_door', 'microwave', 'living_room_appliances', 'temperature', 'humidity', 'visibility', 'wind_speed', 'cloud_cover', 'pressure']

# %%
device_avg = dashboard_df[device_columns].mean()

plt.figure(figsize=(10,5))
device_avg.plot(kind='bar')
plt.title("Average Energy Consumption by Device")
plt.ylabel("Energy Consumption")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dashboard_df['day_type'] = [
    'Weekend' if day >= 5 else 'Weekday'
    for day in dashboard_df.index.dayofweek
]

# %%
weekday_usage = dashboard_df[dashboard_df['day_type'] == 'Weekday'][device_columns].mean()
weekend_usage = dashboard_df[dashboard_df['day_type'] == 'Weekend'][device_columns].mean()

comparison_df = pd.DataFrame({
    'Weekday': weekday_usage,
    'Weekend': weekend_usage
})

comparison_df.plot(kind='bar', figsize=(12,5))
plt.title("Weekday vs Weekend Device Energy Usage")
plt.ylabel("Energy Consumption")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print("Smart Energy Saving Suggestions:\n")

for device in device_columns:
    if comparison_df.loc[device, 'Weekend'] > comparison_df.loc[device, 'Weekday']:
        print(
            f"- {device}: Higher usage on weekends. "
            f"Consider scheduling or reducing usage for energy efficiency."
        )
# Out:
# Smart Energy Saving Suggestions:
#
# - garage_door: Higher usage on weekends. Consider scheduling or reducing usage for energy efficiency.
# - living_room_appliances: Higher usage on weekends. Consider scheduling or reducing usage for energy efficiency.
# - visibility: Higher usage on weekends. Consider scheduling or reducing usage for energy efficiency.
# - wind_speed: Higher usage on weekends. Consider scheduling or reducing usage for energy efficiency.
# - cloud_cover: Higher usage on weekends. Consider scheduling or reducing usage for energy efficiency.
