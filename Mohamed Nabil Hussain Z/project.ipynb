# %% [markdown]
# # Smart Energy Consumption Analysis and Prediction using Machine Learning with Device-Level Insights

# %% [markdown]
# ## Module 1: Data Collection and Understanding

# %% [markdown]
# #### The scope of this project is to collect, organize and analyze smart home energy consumption data at the device level in order to understand energy usage patterns and improve efficiency. The system processes timestamped appliance level power readings to extract insights, identify high consumption devices and enable forecasting of future energy demand using machine learning models. Ultimately, the project aims to support smarter energy usage decisions and reduce overall electricity costs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('./HomeC.csv',low_memory=False)
df.head(10)
# Out:
#          time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0  1451624400  0.932833  0.003483            0.932833         0.000033
# 1  1451624401  0.934333  0.003467            0.934333         0.000000
# 2  1451624402  0.931817  0.003467            0.931817         0.000017
# 3  1451624403  1.022050  0.003483            1.022050         0.000017
# 4  1451624404  1.139400  0.003467            1.139400         0.000133
# 5  1451624405  1.391867  0.003433            1.391867         0.000283
# 6  1451624406  1.366217  0.003450            1.366217         0.000283
# 7  1451624407  1.431900  0.003417            1.431900         0.000250
# 8  1451624408  1.627300  0.003417            1.627300         0.000183
# 9  1451624409  1.735383  0.003417            1.735383         0.000017
#
#    Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# 0        0.020700        0.061917          0.442633     0.124150
# ...

# %% [markdown]
# ### Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503911 entries, 0 to 503910
# Data columns (total 32 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time                 503911 non-null  object
#  1   use [kW]             503910 non-null  float64
#  2   gen [kW]             503910 non-null  float64
#  3   House overall [kW]   503910 non-null  float64
#  4   Dishwasher [kW]      503910 non-null  float64
#  5   Furnace 1 [kW]       503910 non-null  float64
#  6   Furnace 2 [kW]       503910 non-null  float64
#  7   Home office [kW]     503910 non-null  float64
#  8   Fridge [kW]          503910 non-null  float64
#  9   Wine cellar [kW]     503910 non-null  float64
#  10  Garage door [kW]     503910 non-null  float64
#  11  Kitchen 12 [kW]      503910 non-null  float64
#  12  Kitchen 14 [kW]      503910 non-null  float64
#  13  Kitchen 38 [kW]      503910 non-null  float64
# ...

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# time                   0
# use [kW]               1
# gen [kW]               1
# House overall [kW]     1
# Dishwasher [kW]        1
# Furnace 1 [kW]         1
# Furnace 2 [kW]         1
# Home office [kW]       1
# Fridge [kW]            1
# Wine cellar [kW]       1
# Garage door [kW]       1
# Kitchen 12 [kW]        1
# Kitchen 14 [kW]        1
# Kitchen 38 [kW]        1
# Barn [kW]              1
# Well [kW]              1
# Microwave [kW]         1
# Living room [kW]       1
# Solar [kW]             1
# temperature            1
# icon                   1
# humidity               1
# visibility             1
# summary                1
# apparentTemperature    1
# pressure               1
# windSpeed              1
# cloudCover             1
# windBearing            1
# precipIntensity        1
# dewPoint               1
# precipProbability      1
# dtype: int64

# %% [markdown]
# ### Converting time from unix second format to normal date and time format

# %%
df['time']=pd.to_numeric(df['time'], errors='coerce')
df=df.dropna(subset=['time'])
df['time']=pd.to_datetime(df['time'], unit='s')
df=df.set_index('time').sort_index()
print(df.index[:5])
# Out:
# DatetimeIndex(['2016-01-01 05:00:00', '2016-01-01 05:00:01',
#                '2016-01-01 05:00:02', '2016-01-01 05:00:03',
#                '2016-01-01 05:00:04'],
#               dtype='datetime64[ns]', name='time', freq=None)

# %% [markdown]
# ### Checking duplicates

# %%
df.duplicated()
# Out:
# time
# 2016-01-01 05:00:00    False
# 2016-01-01 05:00:01    False
# 2016-01-01 05:00:02    False
# 2016-01-01 05:00:03    False
# 2016-01-01 05:00:04    False
#                        ...
# 2016-01-07 00:58:25    False
# 2016-01-07 00:58:26    False
# 2016-01-07 00:58:27    False
# 2016-01-07 00:58:28    False
# 2016-01-07 00:58:29    False
# Length: 503910, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(171)

# %%
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Exploratory statistics

# %%
df.describe()
# Out:
#             use [kW]       gen [kW]  House overall [kW]  Dishwasher [kW]  \
# count  503739.000000  503739.000000       503739.000000    503739.000000
# mean        0.859250       0.076255            0.859250         0.031378
# std         1.058272       0.128442            1.058272         0.190983
# min         0.000000       0.000000            0.000000         0.000000
# 25%         0.367883       0.003367            0.367883         0.000000
# 50%         0.562500       0.004300            0.562500         0.000017
# 75%         0.970417       0.083983            0.970417         0.000233
# max        14.714567       0.613883           14.714567         1.401767
#
#        Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]    Fridge [kW]  \
# count   503739.000000   503739.000000     503739.000000  503739.000000
# mean         0.099243        0.136825          0.081314       0.063578
# std          0.169078        0.178644          0.104473       0.076203
# ...

# %% [markdown]
# ### Organizing energy readings by device, room and timestamp

# %% [markdown]
# ### Creating device-room-energy table

# %%
df_time_col = df.copy()
#device columns (appliances / circuits)
device_cols = [
    'Dishwasher [kW]',
    'Furnace 1 [kW]',
    'Furnace 2 [kW]',
    'Home office [kW]',
    'Fridge [kW]',
    'Wine cellar [kW]',
    'Garage door [kW]',
    'Kitchen 12 [kW]',
    'Kitchen 14 [kW]',
    'Kitchen 38 [kW]',
    'Barn [kW]',
    'Well [kW]',
    'Microwave [kW]',
    'Living room [kW]'
]
core_energy_cols = [ 'House overall [kW]']
#Map each device / circuit to a room
room_map = {
    'Dishwasher [kW]': 'Kitchen',
    'Fridge [kW]'    : 'Kitchen',
    'Microwave [kW]' : 'Kitchen',
    'Kitchen 12 [kW]': 'Kitchen',
    'Kitchen 14 [kW]': 'Kitchen',
    'Kitchen 38 [kW]': 'Kitchen',

    'Home office [kW]': 'Home Office',
    'Living room [kW]': 'Living Room',

    'Wine cellar [kW]': 'Basement',
    'Garage door [kW]': 'Garage',
    'Barn [kW]'      : 'Outdoor',
    'Well [kW]'      : 'Outdoor',
    'Furnace 1 [kW]' : 'Heating',
    'Furnace 2 [kW]' : 'Heating'
}

df_energy=df[core_energy_cols + device_cols].copy()

df_long=df_energy.reset_index().melt(id_vars=['time'] + core_energy_cols,value_vars=device_cols,var_name='device',value_name='power_kW')

#Adding room information for each device
df_long['room']=df_long['device'].map(room_map).fillna('Unknown')

# %%
df_long
# Out:
#                        time  House overall [kW]            device  power_kW  \
# 0       2016-01-01 05:00:00            0.932833   Dishwasher [kW]  0.000033
# 1       2016-01-01 05:00:01            0.934333   Dishwasher [kW]  0.000000
# 2       2016-01-01 05:00:02            0.931817   Dishwasher [kW]  0.000017
# 3       2016-01-01 05:00:03            1.022050   Dishwasher [kW]  0.000017
# 4       2016-01-01 05:00:04            1.139400   Dishwasher [kW]  0.000133
# ...                     ...                 ...               ...       ...
# 7052341 2016-01-07 00:58:25            1.601233  Living room [kW]  0.000967
# 7052342 2016-01-07 00:58:26            1.599333  Living room [kW]  0.000933
# 7052343 2016-01-07 00:58:27            1.924267  Living room [kW]  0.001000
# 7052344 2016-01-07 00:58:28            1.978200  Living room [kW]  0.000950
# 7052345 2016-01-07 00:58:29            1.990950  Living room [kW]  0.000950
#
#                 room
# 0            Kitchen
# ...

# %%
daily = df_long.resample('D', on='time').mean(numeric_only=True)

plt.figure(figsize=(12,4))
plt.plot(daily.index, daily['House overall [kW]'])
plt.title("Daily Average House Overall Energy Usage")
plt.xlabel("Date")
plt.ylabel("House overall [kW]")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
device_usage = df_long.groupby("device")["power_kW"].sum().sort_values(ascending=False)
plt.figure(figsize=(10,5))
device_usage.plot(kind='bar')
plt.title("Total Energy Consumption by Device (kW)")
plt.ylabel("Total power_kW")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
room_usage = df_long.groupby("room")["power_kW"].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
room_usage.plot(kind='bar')
plt.title("Total Energy Consumption by Room (kW)")
plt.ylabel("Total power_kW")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_long['hour'] = df_long['time'].dt.hour
hourly_pattern = df_long.groupby('hour')['House overall [kW]'].mean()

plt.figure(figsize=(10,4))
plt.plot(hourly_pattern.index, hourly_pattern.values, marker='o')
plt.title("Average Hourly Energy Usage Pattern")
plt.xlabel("Hour of Day")
plt.ylabel("Average House overall [kW]")
plt.grid(True)
plt.show()

# %%
room_usage = df_long.groupby("room")["power_kW"].sum()
plt.figure(figsize=(8,8))
plt.pie(room_usage, labels=room_usage.index, autopct='%1.1f%%')
plt.title("Energy Consumption Share by Room")
plt.show()

# %%
df_long.to_csv("organized_energy_data.csv", index=False)

# %% [markdown]
# ## Module 2: Data Cleaning and Preprocessing

# %% [markdown]
# ### Resampling the data in form of hour

# %%
df_long=pd.read_csv('./organized_energy_data_1.csv')
df_long['time'] = pd.to_datetime(df_long['time'])

# %%
df_long['time_hour'] = df_long['time'].dt.floor('h')
df_hourly = (
    df_long
    .groupby(['time_hour', 'device', 'room'], as_index=False)
    .agg(
        power_kW=('power_kW', 'sum'),              
        house_overall=('House overall [kW]', 'sum')  
    )
    .rename(columns={'time_hour': 'time', 'house_overall': 'House overall [kW]'})
)

# %%
df_hourly['total_device_power'] = (
    df_hourly.groupby('time')['power_kW']
      .transform('sum')
)

# %%
df_hourly
# Out:
#                     time            device         room    power_kW  \
# 0    2016-01-01 05:00:00         Barn [kW]      Outdoor  349.375683
# 1    2016-01-01 05:00:00   Dishwasher [kW]      Kitchen  198.312077
# 2    2016-01-01 05:00:00       Fridge [kW]      Kitchen  239.270767
# 3    2016-01-01 05:00:00    Furnace 1 [kW]      Heating  752.584050
# 4    2016-01-01 05:00:00    Furnace 2 [kW]      Heating  849.664267
# ...                  ...               ...          ...         ...
# 3887 2016-01-12 18:00:00   Kitchen 38 [kW]      Kitchen    0.026276
# 3888 2016-01-12 18:00:00  Living room [kW]  Living Room   95.048914
# 3889 2016-01-12 18:00:00    Microwave [kW]      Kitchen   27.810483
# 3890 2016-01-12 18:00:00         Well [kW]      Outdoor   55.822206
# 3891 2016-01-12 18:00:00  Wine cellar [kW]     Basement  119.880895
#
#       House overall [kW]  total_device_power
# 0            4274.192867         3166.869446
# 1            4274.192867         3166.869446
# ...

# %% [markdown]
# ### Handling missing values

# %%
df_hourly = df_hourly.fillna(method='ffill').fillna(method='bfill')
# Out:
# /tmp/ipykernel_667/3359247515.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_hourly = df_hourly.fillna(method='ffill').fillna(method='bfill')

# %% [markdown]
# ### Outlier detection

# %%
Q1_power=df_hourly['power_kW'].quantile(0.25)
Q3_power=df_hourly['power_kW'].quantile(0.75)
IQR_power=Q3_power-Q1_power

lower_power=Q1_power-1.5*IQR_power
upper_power=Q3_power+1.5*IQR_power

df_hourly['outlier_power']=(df_hourly['power_kW']<lower_power) | (df_hourly['power_kW']>upper_power)

Q1_house=df_hourly['House overall [kW]'].quantile(0.25)
Q3_house=df_hourly['House overall [kW]'].quantile(0.75)
IQR_house=Q3_house - Q1_house

lower_house=Q1_house-1.5*IQR_house
upper_house=Q3_house+1.5*IQR_house
df_hourly['outlier_house']=(df_hourly['House overall [kW]'] < lower_house) |(df_hourly['House overall [kW]'] > upper_house)

Q1_total=df_hourly['total_device_power'].quantile(0.25)
Q3_total=df_hourly['total_device_power'].quantile(0.75)
IQR_total=Q3_total - Q1_total

lower_total=Q1_total-1.5*IQR_total
upper_total=Q3_total+1.5*IQR_total

df_hourly['outlier_total_device']=(df_hourly['total_device_power'] < lower_total) |(df_hourly['total_device_power'] > upper_total)

df_hourly['is_outlier'] = df_hourly['outlier_total_device'] | df_hourly['outlier_house']

outliers_df = df_hourly[df_hourly['is_outlier'] == True]
print(outliers_df.head())
print("Total combined outliers:", len(outliers_df))
print("Total Device column outliers:", df_hourly['outlier_total_device'].sum())
print("House overall column outliers:", df_hourly['outlier_house'].sum())
# Out:
#                  time           device     room    power_kW  \
# 0 2016-01-01 05:00:00        Barn [kW]  Outdoor  349.375683
# 1 2016-01-01 05:00:00  Dishwasher [kW]  Kitchen  198.312077
# 2 2016-01-01 05:00:00      Fridge [kW]  Kitchen  239.270767
# 3 2016-01-01 05:00:00   Furnace 1 [kW]  Heating  752.584050
# 4 2016-01-01 05:00:00   Furnace 2 [kW]  Heating  849.664267
#
#    House overall [kW]  total_device_power  outlier_power  \
# 0         4274.192867         3166.869446          False
# 1         4274.192867         3166.869446          False
# 2         4274.192867         3166.869446          False
# 3         4274.192867         3166.869446           True
# 4         4274.192867         3166.869446           True
#
#    outlier_total_device  outlier_house  is_outlier
# 0                  True           True        True
# 1                  True           True        True
# 2                  True           True        True
# ...

# %% [markdown]
# ### Normalizing values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_hourly_scaled = df_hourly.copy()
df_hourly_scaled[['power_kW','House overall [kW]','total_device_power']] = scaler.fit_transform(df_hourly[['power_kW','House overall [kW]','total_device_power']])
df_hourly_scaled
# Out:
#                     time            device         room  power_kW  \
# 0    2016-01-01 05:00:00         Barn [kW]      Outdoor  0.244733
# 1    2016-01-01 05:00:00   Dishwasher [kW]      Kitchen  0.138910
# 2    2016-01-01 05:00:00       Fridge [kW]      Kitchen  0.167602
# 3    2016-01-01 05:00:00    Furnace 1 [kW]      Heating  0.527188
# 4    2016-01-01 05:00:00    Furnace 2 [kW]      Heating  0.595195
# ...                  ...               ...          ...       ...
# 3887 2016-01-12 18:00:00   Kitchen 38 [kW]      Kitchen  0.000006
# 3888 2016-01-12 18:00:00  Living room [kW]  Living Room  0.066572
# 3889 2016-01-12 18:00:00    Microwave [kW]      Kitchen  0.019470
# 3890 2016-01-12 18:00:00         Well [kW]      Outdoor  0.039093
# 3891 2016-01-12 18:00:00  Wine cellar [kW]     Basement  0.083967
#
#       House overall [kW]  total_device_power  outlier_power  \
# 0               0.328239            0.747414          False
# ...

# %% [markdown]
# ## Module 3: Feature Engineering

# %% [markdown]
# ### Extract relevant time-based features

# %%
df_hourly_scaled['hour'] = df_hourly_scaled['time'].dt.hour
df_hourly_scaled['day'] = df_hourly_scaled['time'].dt.day
df_hourly_scaled['weekday'] = df_hourly_scaled['time'].dt.weekday
df_hourly_scaled['week'] = df_hourly_scaled['time'].dt.isocalendar().week.astype(int)
df_hourly_scaled['month'] = df_hourly_scaled['time'].dt.month

# Weekend flag (0 = weekday, 1 = weekend)
df_hourly_scaled['is_weekend'] = df_hourly_scaled['weekday'].apply(lambda x: 1 if x>=5 else 0)

def season_from_month(m):
    if m in [12,1,2]:
        return "Winter"
    elif m in [3,4,5]:
        return "Spring"
    elif m in [6,7,8]:
        return "Summer"
    else:
        return "Autumn"

df_hourly_scaled['season'] = df_hourly_scaled['month'].apply(season_from_month)

print(df_hourly_scaled.head())
# Out:
#                  time           device     room  power_kW  House overall [kW]  \
# 0 2016-01-01 05:00:00        Barn [kW]  Outdoor  0.244733            0.328239
# 1 2016-01-01 05:00:00  Dishwasher [kW]  Kitchen  0.138910            0.328239
# 2 2016-01-01 05:00:00      Fridge [kW]  Kitchen  0.167602            0.328239
# 3 2016-01-01 05:00:00   Furnace 1 [kW]  Heating  0.527188            0.328239
# 4 2016-01-01 05:00:00   Furnace 2 [kW]  Heating  0.595195            0.328239
#
#    total_device_power  outlier_power  outlier_total_device  outlier_house  \
# 0            0.747414          False                  True           True
# 1            0.747414          False                  True           True
# 2            0.747414          False                  True           True
# 3            0.747414           True                  True           True
# 4            0.747414           True                  True           True
#
# ...

# %% [markdown]
# ### Create lag features and moving averages for time series learning

# %%
df_hourly_scaled = df_hourly_scaled.sort_values(['device', 'time'])

# %%
for lag in [1, 24, 48]:
    df_hourly_scaled[f'power_lag_{lag}'] = (
        df_hourly_scaled.groupby('device')['power_kW'].shift(lag)
    )

for lag in [1, 24, 48]:
    df_hourly_scaled[f'house_lag_{lag}'] = (
        df_hourly_scaled['House overall [kW]'].shift(lag)
    )
for lag in [1, 24, 48]:
    df_hourly_scaled[f'total_device_lag_{lag}'] = (
        df_hourly_scaled['total_device_power'].shift(lag)
    )

# %%
for window in [3, 24, 72]:
    df_hourly_scaled[f'power_roll_{window}'] = (
        df_hourly_scaled.groupby('device')['power_kW']
        .transform(lambda s: s.rolling(window=window, min_periods=1).mean())
    )
for window in [3, 24, 72]:
    df_hourly_scaled[f'house_roll_{window}'] = (
        df_hourly_scaled['House overall [kW]']
        .rolling(window=window, min_periods=1)
        .mean()
    )
for window in [3, 24, 72]:
    df_hourly_scaled[f'total_device_roll_{window}'] = (
        df_hourly_scaled['total_device_power']
        .rolling(window=window, min_periods=1)
        .mean()
    )

# %%
df_features = df_hourly_scaled.dropna().reset_index(drop=True)
print(df_features.shape)
print(df_features.head())
# Out:
# (3220, 35)
#                  time     device     room  power_kW  House overall [kW]  \
# 0 2016-01-03 05:00:00  Barn [kW]  Outdoor  0.254935            0.173207
# 1 2016-01-03 06:00:00  Barn [kW]  Outdoor  0.090435            0.144309
# 2 2016-01-03 07:00:00  Barn [kW]  Outdoor  0.259354            0.156814
# 3 2016-01-03 08:00:00  Barn [kW]  Outdoor  0.412297            0.218636
# 4 2016-01-03 09:00:00  Barn [kW]  Outdoor  0.094185            0.040423
#
#    total_device_power  outlier_power  outlier_total_device  outlier_house  \
# 0            0.341032          False                 False          False
# 1            0.329260          False                 False          False
# 2            0.395112          False                 False          False
# 3            0.502018           True                  True          False
# 4            0.154401          False                  True           True
#
#    is_outlier  ...  total_device_lag_48  power_roll_3  power_roll_24  \
# ...

# %%
df_features = df_features.sort_values("time").reset_index(drop=True)

# %%
df_features.to_csv('features_final.csv',index=False)

# %% [markdown]
# ### Prepare final feature set for ML model input

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_features, test_size=0.15, shuffle=False)
train, val = train_test_split(train, test_size=0.176, shuffle=False)
print(len(train), len(val), len(test))
# Out:
# 2255 482 483

# %% [markdown]
# ## Module 4: Baseline Model Development

# %% [markdown]
# ## Implement Linear Regression as baseline forecasting model

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_features=pd.read_csv('features_final.csv')

# %%
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

df_features['target'] = df_features['House overall [kW]'].shift(-1)
df_features = df_features.dropna().reset_index(drop=True)

scaler=LabelEncoder()
df_features['season']=scaler.fit_transform(df_features['season'])

# Columns to drop
drop_cols = [
    'time',
    'target',
    'device',
    'room',
    'House overall [kW]',
    'power_kW',
    'power_lag_1',
    'power_lag_24',
    'power_lag_48',
    'power_roll_3',
    'power_roll_24',
    'power_roll_72',
    'outlier_power'
    
    
]

X = df_features.drop(columns=drop_cols)
y = df_features['target']

# Train-val-test split again for the target column
train, test = train_test_split(df_features, test_size=0.15, shuffle=False)
train, val = train_test_split(train, test_size=0.176, shuffle=False)

X_train = train.drop(columns=drop_cols)
y_train = train['target']
X_val   = val.drop(columns=drop_cols)
y_val   = val['target']
X_test  = test.drop(columns=drop_cols)
y_test  = test['target']

# Train baseline Linear Regression model
model = LinearRegression()

# %% [markdown]
# ## Train and evaluate baseline using MAE, RMSE metrics.

# %%
model.fit(X_train, y_train)

# Predictions
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

# Evaluation metrics
mae_val = mean_absolute_error(y_val, val_pred)
rmse_val = np.sqrt(mean_squared_error(y_val, val_pred))
mae_test=mean_absolute_error(y_test, test_pred)
rmse_test= np.sqrt(mean_squared_error(y_test, test_pred))

print("validation mae:", mae_val)
print("validation rmse:", rmse_val)
print('test mse:',mae_test)
print('test rmse:',rmse_test)
# Out:
# validation mae: 0.010843246267179111
# validation rmse: 0.013402131239199842
# test mse: 0.015871626615892528
# test rmse: 0.01857504683466955

# %%
r2_val=r2_score(y_val,val_pred)
r2_test=r2_score(y_test,test_pred)
print("r^2 for validation: ",r2_val)
print("r^2 for test: ",r2_test)
# Out:
# r^2 for validation:  -1.695077093095421
# r^2 for test:  -1.1691026915971028

# %% [markdown]
# ## Plot actual vs predicted energy usage

# %%
plt.figure(figsize=(12,4))
plt.plot(y_val.values, label="Actual")
plt.plot(val_pred, label="Predicted")
plt.title("Baseline Model: Actual vs Predicted (Validation Set)")
plt.ylabel("House overall [kW]")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(y_test.values, label="Actual")
plt.plot(test_pred, label="Predicted")
plt.title("Baseline Model: Actual vs Predicted (test Set)")
plt.ylabel("House overall [kW]")
plt.legend()
plt.show()

# %% [markdown]
# ## Saving baseline model

# %%
import joblib

joblib.dump(model, "baseline_linear_model_1.pkl")
print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
joblib.dump(scaler, "scaler_1.pkl")
# Out:
# ['scaler_1.pkl']

# %% [markdown]
# ## Module 5: LSTM Model Development

# %% [markdown]
# ### Design and implement LSTM architecture using TensorFlow/Keras.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
df_long = pd.read_csv("features_final.csv")
df_long = df_long.sort_values('time').reset_index(drop=True)

#df_long['house_delta'] = (
#    df_long['House overall [kW]'].shift(-1) - df_long['House overall [kW]']
#)
df_long['house_delta']=df_long['House overall [kW]'].diff()
df_long = df_long.dropna().reset_index(drop=True)

# %%
features = [
    # Device-level
    'total_device_power',
    'total_device_lag_1',
    'total_device_lag_24',
    'total_device_lag_48',
    'total_device_roll_24',

    # House-level
    'house_lag_1',
    'house_lag_24',
    'house_lag_48',
    'house_roll_24',

    # Time features
    'hour',
    'weekday',
    'is_weekend'
]

target = 'house_delta'

df_model = df_long[features + [target]].dropna().reset_index(drop=True)

# %%
train_size = int(0.7 * len(df_model))
val_size   = int(0.15 * len(df_model))

train_df = df_model.iloc[:train_size]
val_df   = df_model.iloc[train_size:train_size + val_size]
test_df  = df_model.iloc[train_size + val_size:]

X_train, y_train = train_df[features].values, train_df[target].values
X_val, y_val     = val_df[features].values, val_df[target].values
X_test, y_test   = test_df[features].values, test_df[target].values

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)

# %%
SEQ_LEN = 48

def create_sequences(X, y, seq_len):
    X_seq, y_seq = [], []
    for i in range(len(X) - seq_len):
        X_seq.append(X[i:i + seq_len])
        y_seq.append(y[i + seq_len])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train, y_train, SEQ_LEN)
X_val_seq, y_val_seq     = create_sequences(X_val, y_val, SEQ_LEN)
X_test_seq, y_test_seq   = create_sequences(X_test, y_test, SEQ_LEN)

# %%
model = Sequential([
    LSTM(64, return_sequences=True,
         input_shape=(SEQ_LEN, X_train_seq.shape[2])),
    Dropout(0.2),

    LSTM(32),
    Dropout(0.2),

    Dense(1)
])

optimizer = Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='mse'
)

model.summary()
# Out:
# /home/ironman/sem5/ml/aiml/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 48, 64)         │        19,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 48, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ...

# %% [markdown]
# ### Train time series prediction model using sequential energy data.

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq), 
    epochs=50,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0145 - val_loss: 0.0018
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0059 - val_loss: 1.7469e-04
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0038 - val_loss: 2.7793e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0030 - val_loss: 1.4310e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0025 - val_loss: 3.9148e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0022 - val_loss: 6.1616e-05
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0020 - val_loss: 4.3677e-05
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0019 - val_loss: 7.0813e-05
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0018 - val_loss: 5.6639e-05
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0017 - val_loss: 7.6688e-05
# Epoch 11/50
# ...

# %%
y_pred = model.predict(X_test_seq).flatten()

mae = mean_absolute_error(y_test_seq, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))

print(f"LSTM MAE  : {mae:.4f}")
print(f"LSTM RMSE : {rmse:.4f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# LSTM MAE  : 0.0018
# LSTM RMSE : 0.0041

# %%
plt.figure(figsize=(14,5))
plt.plot(y_test_seq, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title("Actual vs Predicted House Delta (LSTM)")
plt.legend()
plt.show()

plt.figure(figsize=(14,4))
plt.plot(y_test_seq - y_pred)
plt.title("Residuals over Time")
plt.show()

# %%
# Define test start index
test_start_idx = train_size + val_size

# Get actual house power from original dataframe
house_full = df_long['House overall [kW]'].values

# Slice test portion
house_test = house_full[test_start_idx : test_start_idx + len(test_df)]

# Align with LSTM sequences
house_test_seq = house_test[SEQ_LEN:]

# Reconstruct predicted house power
house_pred = house_test_seq[:-1] + y_pred[:-1]

# Ground-truth next-step house power
house_actual_next = house_test_seq[1:]

# %%
mae_house = mean_absolute_error(house_actual_next, house_pred)
rmse_house = np.sqrt(mean_squared_error(house_actual_next, house_pred))

print(f"Actual House Power MAE  : {mae_house:.4f} kW")
print(f"Actual House Power RMSE : {rmse_house:.4f} kW")
# Out:
# Actual House Power MAE  : 0.0018 kW
# Actual House Power RMSE : 0.0040 kW

# %%
r2_lstm = r2_score(house_actual_next, house_pred)

print("LSTM Model R² (Test):", r2_lstm)
# Out:
# LSTM Model R² (Test): 0.9049399023660193

# %%
plt.figure(figsize=(14,5))
plt.plot(house_actual_next, label='Actual House Power')
plt.plot(house_pred, label='Predicted House Power')
plt.title("Actual vs Predicted House Power (LSTM)")
plt.ylabel("Power (kW)")
plt.legend()
plt.show()

plt.figure(figsize=(14,4))
plt.plot(house_actual_next - house_pred)
plt.title("Residuals (House Power)")
plt.ylabel("Error (kW)")
plt.show()

# %% [markdown]
# ## Cross Validation and Hyper parameter tuning

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_lstm_model(
    input_shape,
    units1=64,
    units2=32,
    dropout=0.2,
    lr=0.001
):
    model = Sequential([
        LSTM(units1, return_sequences=True, input_shape=input_shape),
        Dropout(dropout),

        LSTM(units2),
        Dropout(dropout),

        Dense(1)
    ])

    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss='mse'
    )
    return model

# %%
def reconstruct_power(house_seq, delta_pred):
    pred = house_seq[:-1] + delta_pred[:-1]
    actual = house_seq[1:]
    return actual, pred

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import numpy as np

tscv = TimeSeriesSplit(n_splits=4)
param_grid = [ {"units1": 64, "units2": 32, "dropout": 0.2, "lr": 0.001, "batch": 64}, 
               # {"units1": 128, "units2": 64, "dropout": 0.3, "lr": 0.001, "batch": 64},
               {"units1": 64, "units2": 32, "dropout": 0.3, "lr": 0.0005, "batch": 32} ]
results = []

for params in param_grid:
    fold_rmse = []

    for fold, (train_idx, val_idx) in enumerate(tscv.split(X_train_seq)):

        X_tr, X_va = X_train_seq[train_idx], X_train_seq[val_idx]
        y_tr, y_va = y_train_seq[train_idx], y_train_seq[val_idx]

        # Train model
        model = build_lstm_model(
            input_shape=(SEQ_LEN, X_tr.shape[2]),
            units1=params["units1"],
            units2=params["units2"],
            dropout=params["dropout"],
            lr=params["lr"]
        )

        model.fit(
            X_tr, y_tr,
            epochs=30,
            batch_size=params["batch"],
            verbose=0
        )
        y_val_delta_pred = model.predict(X_va, verbose=0).flatten()

        start = train_size + val_size - len(X_train_seq) + val_idx[0]
        end   = start + len(val_idx) + SEQ_LEN

        house_val = df_long['House overall [kW]'].values[start:end]
        house_val_seq = house_val[SEQ_LEN:]

        actual, pred = reconstruct_power(house_val_seq, y_val_delta_pred)

        rmse = np.sqrt(mean_squared_error(actual, pred))
        fold_rmse.append(rmse)

    results.append({
        "params": params,
        "mean_rmse": np.mean(fold_rmse)
    })

results = sorted(results, key=lambda x: x["mean_rmse"])

for r in results:
    print(r)
# Out:
# 2026-01-05 15:02:16.219178: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/ironman/sem5/ml/aiml/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/ironman/sem5/ml/aiml/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ...

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
best = results[0]["params"]

final_model = build_lstm_model(
    input_shape=(SEQ_LEN, X_train_seq.shape[2]),
    units1=best["units1"],
    units2=best["units2"],
    dropout=best["dropout"],
    lr=best["lr"]
)

final_model.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=50,
    batch_size=best["batch"],
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# /home/ironman/sem5/ml/aiml/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.0227 - val_loss: 3.2173e-04
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0097 - val_loss: 6.0676e-04
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0059 - val_loss: 1.7066e-04
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0044 - val_loss: 8.8841e-05
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0038 - val_loss: 6.4988e-05
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0034 - val_loss: 2.3887e-05
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0029 - val_loss: 1.0062e-04
# Epoch 8/50
# ...

# %%
# Define test start index
test_start_idx = train_size + val_size

# Get actual house power from original dataframe
house_full = df_long['House overall [kW]'].values

# Slice test portion
house_test = house_full[test_start_idx : test_start_idx + len(test_df)]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
y_pred_delta = final_model.predict(X_test_seq, verbose=0).flatten()

house_test = house_full[
    test_start_idx : test_start_idx + len(test_df)
]

house_test_seq = house_test[SEQ_LEN:]

house_pred = house_test_seq[:-1] + y_pred_delta[:-1]
house_actual_next = house_test_seq[1:]

mae  = mean_absolute_error(house_actual_next, house_pred)
rmse = np.sqrt(mean_squared_error(house_actual_next, house_pred))
r2   = r2_score(house_actual_next, house_pred)

print("Tuned LSTM Performance")
print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# Tuned LSTM Performance
# MAE  : 0.0023
# RMSE : 0.0044
# R²   : 0.8854

# %%
plt.figure(figsize=(14,5))
plt.plot(house_actual_next, label="Actual")
plt.plot(house_pred, label="Predicted")
plt.title("Tuned LSTM – Actual vs Predicted House Power")
plt.ylabel("Power (kW)")
plt.legend()
plt.show()

plt.figure(figsize=(14,4))
plt.plot(house_actual_next - house_pred)
plt.title("Residuals (House Power)")
plt.ylabel("Error (kW)")
plt.show()

# %% [markdown]
# ## Module 6: Model Evaluation and Integration

# %% [markdown]
# ### Evaluate models using RMSE, MAE, and R² score.

# %% [markdown]
# ## Before Cross Validation

# %%
import pandas as pd

comparison = pd.DataFrame({
    'Model': ['Linear Regression', 'LSTM'],
    'MAE': [mae_test, mae_house],
    'RMSE': [rmse_test, rmse_house],
    'R²': [r2_test_baseline, r2_lstm]
})

print(comparison)
# Out:
#                Model       MAE      RMSE        R²
# 0  Linear Regression  0.015872  0.018575 -1.169103
# 1               LSTM  0.001775  0.004041  0.904940

# %% [markdown]
# ## After Cross Validation and hyper parameter tuning

# %%
import pandas as pd

comparison = pd.DataFrame({
    'Model': ['Linear Regression', 'LSTM'],
    'MAE': [mae_test, mae],
    'RMSE': [rmse_test, rmse],
    'R²': [r2_test, r2]
})

print(comparison)
# Out:
#                Model       MAE      RMSE        R²
# 0  Linear Regression  0.015872  0.018575 -1.169103
# 1               LSTM  0.002299  0.004438  0.885358

# %% [markdown]
# ### Select best-performing model and save trained weights.

# %% [markdown]
# #### From the evaluation metrics, it is clear that lstm has performed well so it is chosen as the best model

# %%
model.save("lstm_energy_model.keras")
np.save("lstm_scaler.npy", scaler.mean_)
np.save("lstm_scaler_scale.npy", scaler.scale_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Convert model into Flask-compatible prediction function.

# %%
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# Load model
lstm_model = tf.keras.models.load_model("lstm_energy_model.keras",compile=False)

# Load scaler
scaler_mean = np.load("lstm_scaler.npy")
scaler_scale = np.load("lstm_scaler_scale.npy")
scaler = StandardScaler()
scaler.mean_ = scaler_mean
scaler.scale_ = scaler_scale

SEQ_LEN = 48

def predict_next_house_power(feature_sequence_48):
    # Scale
    feature_sequence_48 = np.array(feature_sequence_48)
    X_scaled = scaler.transform(feature_sequence_48)

    # Reshape to (1, 48, features)
    X_input = np.expand_dims(X_scaled, axis=0)

    # Predict delta
    delta_pred = lstm_model.predict(X_input)[0][0]

    # Reconstruct next house power
    last_house_value = feature_sequence_48[-1, 0] 
    next_house_power = last_house_value + delta_pred

    return float(next_house_power)

# %% [markdown]
# ### Test model predictions using sample inputs.

# %%
test_seq = [
    [0.5, 0.4, 0.3, 0.2, 0.6, 0.5, 0.4, 0.3, 0.6, 12, 2, 0],
   [0.52, 0.41, 0.31, 0.21, 0.58, 0.48, 0.38, 0.29, 0.59, 12, 2, 0],
    [0.49, 0.39, 0.29, 0.19, 0.57, 0.47, 0.36, 0.28, 0.58, 13, 2, 0],
    [0.53, 0.43, 0.33, 0.23, 0.60, 0.50, 0.40, 0.32, 0.61, 13, 2, 0]
    
]*12
energy = predict_next_house_power(test_seq)
print("Future Energy Use:", energy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# Future Energy Use: 0.5039365726709366

# %% [markdown]
# ## Module 7: Dashboard and Visualization

# %%
import pandas as pd
df_long=pd.read_csv('./features_final.csv')

# %%
df_long['time'] = pd.to_datetime(df_long['time'])
df_long['date'] = df_long['time'].dt.date
df_long['hour'] = df_long['time'].dt.hour
df_long['day'] = df_long['time'].dt.day_name()
df_long['week'] = df_long['time'].dt.isocalendar().week
df_long['month'] = df_long['time'].dt.month_name()

# Aggregations
hourly = df_long.groupby('hour')['House overall [kW]'].mean()
daily = df_long.groupby('date')['House overall [kW]'].sum()
weekly = df_long.groupby('week')['House overall [kW]'].sum()
monthly = df_long.groupby('month')['House overall [kW]'].sum()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))
plt.plot(hourly.index, hourly.values, marker='o')
plt.title("Hourly Energy Consumption")
plt.xlabel("Hour of Day")
plt.ylabel("Total kW")
plt.grid(True)
plt.tight_layout()
#plt.savefig("static/hourly.png")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(daily.index, daily.values)
plt.title("Daily Energy Consumption")
plt.xlabel("Day")
plt.ylabel("kW")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
#plt.savefig("static/daily.png")
plt.show()

# %%
device_usage = df_long.groupby('device')['power_kW'].sum()

plt.figure(figsize=(7,7))
device_usage.plot(kind='pie', autopct='%1.1f%%')
plt.title("Device-wise Energy Contribution")
plt.ylabel("")
plt.tight_layout()
#plt.savefig("static/device_pie.png")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.bar(device_usage.index, device_usage.values)
plt.title("Device-wise Total Energy Usage (kW)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
def smart_suggestions(df):
    suggestions = []

    # 1. High evening consumption
    evening = df[df['hour'].between(18, 23)]
    if evening['House overall [kW]'].mean() > df['House overall [kW]'].mean() * 1.3:
        suggestions.append("High evening energy spikes detected — consider using timers or smart plugs.")

    # 2. Standby devices running at night
    night = df[df['hour'].between(0, 5)]
    standby = night.groupby("device")["power_kW"].mean()
    for dev, val in standby.items():
        if val > 0.05:  # threshold
            suggestions.append(f"{dev} seems to consume power at night — check if it can be switched off.")

    # 3. Device using too much compared to others
    device_totals = df.groupby("device")["power_kW"].sum()
    high_use = device_totals[device_totals > device_totals.mean() * 1.5]
    for dev in high_use.index:
        suggestions.append(f"{dev} consumes significantly more power — consider energy-efficient alternatives.")

  
    suggestions.append("Forecast-based: Expected rise in usage tomorrow. Plan heavy tasks for off-peak hours.")

    return suggestions

tips = smart_suggestions(df_long)
for t in tips:
    print("•", t)
# Out:
# • Barn [kW] seems to consume power at night — check if it can be switched off.
# • Fridge [kW] seems to consume power at night — check if it can be switched off.
# • Furnace 1 [kW] seems to consume power at night — check if it can be switched off.
# • Furnace 2 [kW] seems to consume power at night — check if it can be switched off.
# • Home office [kW] seems to consume power at night — check if it can be switched off.
# • Furnace 1 [kW] consumes significantly more power — consider energy-efficient alternatives.
# • Furnace 2 [kW] consumes significantly more power — consider energy-efficient alternatives.
# • Home office [kW] consumes significantly more power — consider energy-efficient alternatives.
# • Forecast-based: Expected rise in usage tomorrow. Plan heavy tasks for off-peak hours.
